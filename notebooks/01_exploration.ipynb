# %% [markdown]
# # Exploration - Competitions
#
# Goal: to identify the `competition_id` of the Campeonato Brasileiro Série A, which will be used to filter the other tables in the dataset.

# %%
import pandas as pd

# %% [markdown]
# ## Loading the data

# %%
df_competitions = pd.read_csv('../data/raw/competitions.csv')

# %% [markdown]
# ## Exploring the structure

# %%
df_competitions.head()
# Out:
#   competition_id       competition_code                   name  \
# 0             A1             bundesliga             bundesliga
# 1           AFAC          afc-asian-cup          afc-asian-cup
# 2           AFCN  africa-cup-of-nations  africa-cup-of-nations
# 3           ARG1        torneo-apertura        torneo-apertura
# 4           AUS1           a-league-men           a-league-men
#
#                 sub_type                       type  country_id country_name  \
# 0             first_tier            domestic_league         127      Austria
# 1          afc_asian_cup  national_team_competition          -1          NaN
# 2  africa_cup_of_nations  national_team_competition          -1          NaN
# 3             first_tier            domestic_league           9    Argentina
# 4             first_tier            domestic_league          12    Australia
#
#   domestic_league_code confederation  total_clubs  \
# 0                   A1        europa         12.0
# ...

# %%
df_competitions.columns
# Out:
# Index(['competition_id', 'competition_code', 'name', 'sub_type', 'type',
#        'country_id', 'country_name', 'domestic_league_code', 'confederation',
#        'total_clubs', 'url'],
#       dtype='str')

# %%
df_competitions.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   competition_id        65 non-null     str
#  1   competition_code      65 non-null     str
#  2   name                  65 non-null     str
#  3   sub_type              65 non-null     str
#  4   type                  65 non-null     str
#  5   country_id            65 non-null     int64
#  6   country_name          53 non-null     str
#  7   domestic_league_code  53 non-null     str
#  8   confederation         65 non-null     str
#  9   total_clubs           50 non-null     float64
#  10  url                   65 non-null     str
# dtypes: float64(1), int64(1), str(9)
# memory usage: 5.7 KB

# %% [markdown]
# ## Finding the Brasileirão Serie A

# %%
df_competitions[df_competitions['country_name'] == 'Brazil']
# Out:
#   competition_id               competition_code  \
# 8           BRA1  campeonato-brasileiro-serie-a
#
#                             name    sub_type             type  country_id  \
# 8  campeonato-brasileiro-serie-a  first_tier  domestic_league          26
#
#   country_name domestic_league_code confederation  total_clubs  \
# 8       Brazil                 BRA1       amerika         20.0
#
#                                                  url
# 8  https://www.transfermarkt.co.uk/campeonato-bra...

# %% [markdown]
# ## Investigating continental competitions (Copa do Brasil, Libertadores)

# %%
df_competitions['type'].unique()
# Out:
# <StringArray>
# [          'domestic_league', 'national_team_competition',
#                      'other',              'domestic_cup',
#          'international_cup']
# Length: 5, dtype: str

# %%
df_competitions[(df_competitions['type'] == 'international_cup')]
# Out:
#    competition_id                  competition_code  \
# 12             CL             uefa-champions-league
# 13            CLQ  uefa-champions-league-qualifying
# 64            USC                    uefa-super-cup
#
#                                 name                          sub_type  \
# 12             uefa-champions-league             uefa_champions_league
# 13  uefa-champions-league-qualifying  uefa_champions_league_qualifying
# 64                    uefa-super-cup                    uefa_super_cup
#
#                  type  country_id country_name domestic_league_code  \
# 12  international_cup          -1          NaN                  NaN
# 13  international_cup          -1          NaN                  NaN
# 64  international_cup          -1          NaN                  NaN
#
#    confederation  total_clubs  \
# 12        europa          NaN
# 13        europa          NaN
# 64        europa          NaN
#
#                                                   url
# ...

# %%
df_competitions[df_competitions['type'] == 'international_cup'].shape
# Out:
# (3, 11)

# %%
df_competitions[df_competitions['type'] == 'international_cup']['confederation'].unique()
# Out:
# <StringArray>
# ['europa']
# Length: 1, dtype: str

# %%
df_competitions[df_competitions['name'].str.contains('liber|sudamericana|conmebol', case=False)]
# Out:
# Empty DataFrame
# Columns: [competition_id, competition_code, name, sub_type, type, country_id, country_name, domestic_league_code, confederation, total_clubs, url]
# Index: []

# %%
df_competitions[df_competitions['name'].str.contains('brazil', case=False)]
# Out:
# Empty DataFrame
# Columns: [competition_id, competition_code, name, sub_type, type, country_id, country_name, domestic_league_code, confederation, total_clubs, url]
# Index: []

# %%
df_competitions[df_competitions['country_name'] == 'Brazil']
# Out:
#   competition_id               competition_code  \
# 8           BRA1  campeonato-brasileiro-serie-a
#
#                             name    sub_type             type  country_id  \
# 8  campeonato-brasileiro-serie-a  first_tier  domestic_league          26
#
#   country_name domestic_league_code confederation  total_clubs  \
# 8       Brazil                 BRA1       amerika         20.0
#
#                                                  url
# 8  https://www.transfermarkt.co.uk/campeonato-bra...

# %% [markdown]
# ## Conclusion
#
# - Brazilian Série A competition_id: BRA1
# - This dataset (davidcariboo/player-scores) covers only the Brazilian Série A —
#   no Copa do Brasil, Libertadores, or other continental competitions were found
#   for Brazil in this source
# - Decision: proceed with Série A only for v1 of the project; other competitions
#   may be added later using additional data sources
